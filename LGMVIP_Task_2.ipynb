# %% [markdown]
# ## **LGMVIP Task 2**
#
# ### *Level : Beginner Level Task*
#
# ### *Task : Image to Pencil Sketch with Python*
#
# ### *Author : Rupsha Chatterjee*

# %% [markdown]
# ### **Importing libraries**

# %%
from google.colab.patches import cv2_imshow
import cv2

# %% [markdown]
# ### **Loading the image**

# %%
image = cv2.imread("/content/image.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FA89C88B850>

# %% [markdown]
# ### **Convert to greyscale image**

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=259x194 at 0x7FA89C822D90>

# %% [markdown]
# ### **Convert to inverted image**

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=259x194 at 0x7FA89C8222D0>

# %% [markdown]
# ### **Convert to pencil sketch**

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=259x194 at 0x7FA89C88B410>

# %% [markdown]
# ### **Display both original and pencil sketch image**

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FA89B7BC290>
# <PIL.Image.Image image mode=L size=259x194 at 0x7FA89B7BC610>
